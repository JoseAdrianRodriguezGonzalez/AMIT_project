# %% [markdown]
# # First insight, I have to see my dataframe}

# %%
import os
import pandas as pd
files=os.listdir("./data")
files
df=pd.read_csv('./data/acuario.csv')
df
# Out:
#                                                 Titulo  \
# 0                                              Nível 2
# 1    Fue divertida, entretenida y adecuada a varias...
# 2                                  Bueno yventretenido
# 3                                 Un día en el acuario
# 4                                    Experiencia michi
# ..                                                 ...
# 505                                       Excelente 👍🏻
# 506                                  Me gustó bastante
# 507                      Increíble, bastante divertido
# 508                                         Fantastica
# 509  La experiencia es buena hay bastantes actividades
#
#                                                 Review  TipoViaje  \
# 0    Pues la dinámica de ruta extrema como también ...        NaN
# 1    Buena, personal amable y atracciones didáctica...        NaN
# 2    Es muy bonito solo al principio se me hizo un ...        NaN
# 3    Mi experiencia es positiva, una recomendación ...        NaN
# 4    Falta de coordinación todo lo de más muy bien ...        NaN
# ..                                                 ...        ...
# 505  Muy lindoooo, excelente lugar, actividades muy...        NaN
# 506  Muy divertido y entretenido con las opciones i...        NaN
# 507  Todo muy divertido, con muchas cosas que hacer...        NaN
# 508  La experiencia es muy agradable, se aprecia de...        NaN
# 509  La experiencia es padre ya que no solo es el a...        NaN
#
#      Calificacion OrigenAutor         FechaOpinion FechaEstadia
# 0               4         NaN  4 de agosto de 2025  ago de 2025
# 1               4         NaN  4 de agosto de 2025  ago de 2025
# 2               4         NaN  4 de agosto de 2025  ago de 2025
# 3               4         NaN  4 de agosto de 2025  ago de 2025
# 4               4         NaN  3 de agosto de 2025  ago de 2025
# ..            ...         ...                  ...          ...
# 505             4         NaN  24 de enero de 2024  ene de 2024
# 506             5         NaN  23 de enero de 2024  ene de 2024
# 507             5         NaN  23 de enero de 2024  ene de 2024
# 508             5         NaN  23 de enero de 2024  ene de 2024
# 509             5         NaN  23 de enero de 2024  ene de 2024
#
# [510 rows x 7 columns]

# %% [markdown]
# # Eliminate nan

# %%
df[['Titulo','Review','TipoViaje','Calificacion','OrigenAutor','FechaOpinion','FechaEstadia']].isna().sum()
# Out:
# Titulo            0
# Review            0
# TipoViaje       510
# Calificacion      0
# OrigenAutor     482
# FechaOpinion      0
# FechaEstadia      0
# dtype: int64

# %%
df.drop(columns=['TipoViaje','OrigenAutor'])
docs=(df['Titulo'].fillna('')+" "+ df['Review'].fillna('')).tolist
docs
# Out:
# <bound method IndexOpsMixin.tolist of 0      Nível 2 Pues la dinámica de ruta extrema como ...
# 1      Fue divertida, entretenida y adecuada a varias...
# 2      Bueno yventretenido Es muy bonito solo al prin...
# 3      Un día en el acuario Mi experiencia es positiv...
# 4      Experiencia michi Falta de coordinación todo l...
#                              ...
# 505    Excelente 👍🏻 Muy lindoooo, excelente lugar, ac...
# 506    Me gustó bastante Muy divertido y entretenido ...
# 507    Increíble, bastante divertido Todo muy diverti...
# 508    Fantastica La experiencia es muy agradable, se...
# 509    La experiencia es buena hay bastantes activida...
# Length: 510, dtype: object>

# %%
from bertopic import BERTopic
topic_model=BERTopic(language='spanish')
topics,probs=topic_model.fit_transform(docs)
